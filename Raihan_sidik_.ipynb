# %%
nama = 'Raihan Sidik'

# %%
nama = "raihan"
usia = 20
lajang = True

print(str)
print(type(usia))
print(type(lajang))
# Out:
# <class 'str'>
# <class 'int'>
# <class 'bool'>

# %%
usia = input ('masukan usia anda : ')
print(type(usia))
# Out:
# masukan usia anda : 12
# <class 'str'>

# %%
panjang = input ('masukan panjang anda: ')
lebar =  input ('masukan lebar anda :')
# Out:
# masukan panjang anda: 14
# masukan lebar anda :15

# %%
a = 10 / 2
print(type(a))
b = 1/2
print(type(b))

# %%
panjang = input ('masukan panjang anda: ')
lebar =  input ('masukan lebar anda :')
print('luas =', panjang * lebar)

# %%
panjang = int (input ('masukan panjang anda: '))
lebar = float  (input ('masukan lebar anda :'))
print('luas =', panjang * lebar)
# Out:
# masukan panjang anda: 2
# masukan lebar anda :5
# luas = 10.0

# %%
nama = 'walid'
tahun_lahir =2005

print(nama + 'lahir di tahun '+ str(tahun_lahir))
